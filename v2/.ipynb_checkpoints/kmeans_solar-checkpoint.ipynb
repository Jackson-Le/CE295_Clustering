# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import os

from dotenv import load_dotenv
import itertools

# %%
# env variables
load_dotenv()
# edit the environment file to your datafile
data_path = os.environ.get("data_path")

# %%
data_path
# Out:
# 'C:\\Users\\orcal\\Documents\\UCB\\CE295\\Project\\data'

# %%
os.chdir(data_path)
df_tx = pd.read_csv('15minute_data_austin.csv')
#df_ca = pd.read_csv('15minute_data_california.csv') not using for our project
df_ny = pd.read_csv('15minute_data_newyork.csv')

# %%
meta = pd.read_csv('metadata.csv').iloc[1:]
meta.head()
# Out:
#   dataid active_record                    building_type    city  state  \
# 1   2836           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 2   2743           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 3   5323           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 4   8560           NaN  Single-Family Home 001 (Master)  Austin  Texas
# 5   3313           NaN  Single-Family Home 001 (Master)  Austin  Texas
#
#   egauge_1min_min_time egauge_1min_max_time egauge_1min_data_availability  \
# 1                  NaN                  NaN                           NaN
# 2                  NaN                  NaN                           NaN
# 3                  NaN                  NaN                           NaN
# 4                  NaN                  NaN                           NaN
# 5                  NaN                  NaN                           NaN
#
#   egauge_1s_min_time egauge_1s_max_time  ... survey_2017 survey_2019  \
# 1                NaN                NaN  ...         NaN         NaN
# 2                NaN                NaN  ...         NaN         NaN
# 3                NaN                NaN  ...         NaN         NaN
# 4                NaN                NaN  ...         NaN         NaN
# 5                NaN                NaN  ...         NaN         NaN
#
#   program_579 program_baseline program_energy_internet_demo  \
# 1         NaN              NaN                          yes
# 2         NaN              NaN                          yes
# 3         NaN              yes                          yes
# 4         NaN              yes                          yes
# 5         NaN              yes                          yes
#
#   program_lg_appliance program_verizon program_ccet_group  \
# 1                  NaN             NaN                NaN
# 2                  NaN             NaN                NaN
# 3                  NaN             NaN                NaN
# 4                  NaN             NaN                NaN
# 5                  NaN             NaN                NaN
#
#   program_civita_group program_shines
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# 5                  NaN            NaN
#
# [5 rows x 127 columns]

# %%
solar = set(meta[meta['pv'] == 'yes']['dataid'].unique())

# %%
def clean_up_dataset(dataframe):
    sorted_df = dataframe.sort_values(by= ['local_15min'])
    all_sorted_time = sorted_df['local_15min'].unique()
    time_ids = {}
    unique_ids = {}
    counter = 0
    dataframe = dataframe.fillna(0)
    
    # Assign a unique numerical id to each timestamp
    for i in all_sorted_time:
        time_ids.update({i: counter})
        unique_ids.update({counter: i})
        counter += 1

    
    def get_front_back(df, date):
        if time_ids[date] - 1 > 0:
            back = unique_ids[time_ids[date] - 1]
        else:
            back = date
        if time_ids[date] + 1 < len(unique_ids):
            front = unique_ids[time_ids[date] + 1]
        else:
            front = date
        return (df[df['local_15min'] == front]['grid'], df[df['local_15min'] == back]['grid'])
    
    def missing_times(lst1, lst2):
        # takes unique list and finds the difference in other list
        return list(set(lst1).difference(lst2))
    
    # Append missing data values
    time_labels = []
    grid_interpret = []
    data_labels =[]
    num_uid = 0
    for k in dataframe['dataid'].unique():
        num_uid += 1
        cur_mis = missing_times(all_sorted_time, dataframe[dataframe['dataid'] == k]['local_15min'].unique())
        print(f"Household ID {k} is missing {len(cur_mis)} timestamps.")
        for j in cur_mis:
            time_labels += [j]
            grid_interpret += [np.nan]
            data_labels += [k]
            
    sorted_id = dataframe.append(pd.DataFrame({'local_15min': time_labels, 'grid': grid_interpret, 'dataid': data_labels}),
                    ignore_index = True)
    
    # Resort by data labels
    sorted_id = sorted_id.sort_values(by= ['dataid'])
    sorted_id.reset_index(drop=True,inplace=True)

    # Apply interpolation by indexing into separate UIDs
    df_list = []
    for uid in sorted_id['dataid'].unique():
        grid_pts = sorted_id.loc[sorted_id['dataid']==uid,:].copy()
        grid_pts = grid_pts.sort_values(by=['local_15min'],ignore_index=True)
        interp = grid_pts.interpolate(method='polynomial',order = 5)
        df_list.append(interp)
      
    sorted_id = pd.concat(df_list,ignore_index=True)
    return sorted_id

# %%
# sorted_cleaned_tx = clean_up_dataset(df_tx)
# sorted_cleaned_ca = clean_up_dataset(df_ca)
sorted_cleaned_ny = clean_up_dataset(df_ny)
# Out:
# Household ID 4550 is missing 0 timestamps.
# Household ID 558 is missing 0 timestamps.
# Household ID 2358 is missing 0 timestamps.
# Household ID 3700 is missing 0 timestamps.
# Household ID 1417 is missing 0 timestamps.
# Household ID 5679 is missing 0 timestamps.
# Household ID 5058 is missing 0 timestamps.
# Household ID 2318 is missing 0 timestamps.
# Household ID 5997 is missing 0 timestamps.
# Household ID 950 is missing 0 timestamps.
# Household ID 5982 is missing 0 timestamps.
# Household ID 5587 is missing 0 timestamps.
# Household ID 1222 is missing 0 timestamps.
# Household ID 387 is missing 0 timestamps.
# Household ID 3000 is missing 0 timestamps.
# Household ID 4283 is missing 0 timestamps.
# Household ID 3488 is missing 0 timestamps.
# Household ID 3517 is missing 0 timestamps.
# Household ID 9053 is missing 0 timestamps.
# Household ID 3996 is missing 0 timestamps.
# Household ID 27 is missing 1 timestamps.
# Household ID 142 is missing 0 timestamps.
# Household ID 914 is missing 0 timestamps.
# Household ID 2096 is missing 0 timestamps.
# Household ID 1240 is missing 0 timestamps.

# %%
def get_date(date):
    if type(date) == str:
        dtobj = dt.datetime.strptime(date, '%Y-%m-%d %H:%M:%S-%f')
        return dtobj.year * 10000 + dtobj.month * 100 + dtobj.day
    return date.year * 10000 + date.month * 100 + date.day

def all_days(df):
    days = []
    i = 96
    while i < len(df):
        days.append(get_date(df.iloc[i-1]['local_15min']))
    return days

# %%
def multi_index_dataframe(df):
    df_days_all = df[df['dataid'] == df['dataid'][0]]['local_15min']
    df_days = []
    i = 96
    while i < len(df_days_all):
        df_days += [get_date(df_days_all[i-1])]
        i += 96
    iterables = [df['dataid'].unique(), df_days]
    multi_index = pd.MultiIndex.from_product(iterables, names=["dataid", "date"])    
    vals = []
    for houseid in df['dataid'].unique():
        temp = df[df['dataid'] == houseid]
        temp_dict = {}
        i = 96
        while i < len(temp):
            vals_temp = list(temp[i - 96:i]['grid'])
            vals += [vals_temp]
            i += 96
    df_final = pd.DataFrame(vals, index = multi_index, columns = np.arange(96))
    return df_final

# %%
def solar_array(dataids, solarids):
    solars = []
    nonsolar = []
    for i in dataids:
        if str(i) in solarids:
            solars += [i]
        else:
            nonsolar += [i]
    return (solars, nonsolar)

# %%
def multi_index_dataframe_solar(df):
    df_days_all = df[df['dataid'] == df['dataid'][0]]['local_15min']
    df_days = []
    i = 96
    while i < len(df_days_all):
        df_days += [get_date(df_days_all[i-1])]
        i += 96
    iterables = [solar_array(df['dataid'].unique(), solar)[0], df_days]
    multi_index = pd.MultiIndex.from_product(iterables, names=["dataid", "date"])    
    vals = []
    for houseid in df['dataid'].unique():
        if str(houseid) in solar:
            temp = df[df['dataid'] == houseid]
            temp_dict = {}
            i = 96
            while i < len(temp):
                vals_temp = list(temp[i - 96:i]['grid'])
                vals += [vals_temp]
                i += 96
    df_final_solar = pd.DataFrame(vals, index = multi_index, columns = np.arange(96))
    return df_final_solar

def multi_index_dataframe_no_solar(df):
    df_days_all = df[df['dataid'] == df['dataid'][0]]['local_15min']
    df_days = []
    i = 96
    while i < len(df_days_all):
        df_days += [get_date(df_days_all[i-1])]
        i += 96
    iterables = [solar_array(df['dataid'].unique(), solar)[1], df_days]
    multi_index = pd.MultiIndex.from_product(iterables, names=["dataid", "date"])    
    vals = []
    for houseid in df['dataid'].unique():
        if str(houseid) not in solar:
            temp = df[df['dataid'] == houseid]
            temp_dict = {}
            i = 96
            while i < len(temp):
                vals_temp = list(temp[i - 96:i]['grid'])
                vals += [vals_temp]
                i += 96
    df_final_no_solar = pd.DataFrame(vals, index = multi_index, columns = np.arange(96))
    return df_final_no_solar

# %%
multi_ny_solar = multi_index_dataframe_solar(sorted_cleaned_ny)
multi_ny_no_solar = multi_index_dataframe_no_solar(sorted_cleaned_ny)

# %%
def plot_from_multi(multi_df: 'DataFrame', day: int): # day is the day stamp to plot
    day_str = str(day)
    plt.figure(figsize = (15,8),dpi=300)
    ax = plt.gca()
    household_use = multi_df.xs(day,level=1) # index on second level only
    
    # Create 15 minute intervals
    def pad_hours(string):
        if len(string)<2:
            string = '0'+string
        return string
    
    hours = np.arange(25)
    hours = [pad_hours(str(hour)) for hour in hours]
    #minutes = ['00','15','30','45']
    #day_intervals = sorted(list(itertools.product(hours,minutes)))
    
    # Plot energy use data
    for uid in household_use.index:
        energy_use = household_use.loc[uid,:]
        plt.plot(np.arange(len(energy_use)),energy_use)
    
    ax.set_xticks(np.arange(0,len(energy_use)+4,4))
    ax.set_xticklabels(hours)
    ax.set_xlabel('Hours', size = 16)
    ax.set_ylabel('Energy Use', size = 16)
    ax.set_title(f'Energy use for {day_str[-2:]}-{day_str[-4:-2]}-{day_str[0:4]}', size = 16) # day-month-year
    fig = plt.gcf()
    
    #plt.show()
    return fig

# %%
day = 20190502
fig = plot_from_multi(multi_ny_solar,day)
fig.savefig(f'{day}_use.png',bbox_inches='tight')
plt.show()

# %%
day = 20190502
fig = plot_from_multi(multi_ny_no_solar,day)
fig.savefig(f'{day}_use.png',bbox_inches='tight')
plt.show()

# %%
def make_power_consumption_graph(dataframe):
    ax = plt.gca()
    # gets the total consumption from grid per hour
    def get_total_consumption(df, dateindex):
        consumption = np.zeros(96)
        for i in df.index.levels[0]:
            consumption += df.loc[i, dateindex]
        return consumption
    # creates the histogram array
    def congregate_times(df):
        histogram_of_days = np.zeros(len(df.index.levels[1]))
        index = 0
        for i in df.index.levels[1]:
            histogram_of_days[index] += get_total_consumption(df, i).idxmax()/4
            index += 1
        return histogram_of_days
    # Greates graph
    def pad_hours(string):
        if len(string)<2:
            string = '0'+string
        return string
    
    hours = np.arange(25)
    hours = [pad_hours(str(hour)) for hour in hours]
    
    # Plot energy use data
    max_energy = congregate_times(dataframe)
    plt.hist(max_energy, bins = np.arange(0,24))
    ax.set_xlabel('Hours')
    ax.set_ylabel('Peak draw frequency in a year')
    ax.set_title(f'Max Power Draw') # day-month-year
    fig = plt.gcf()
    
    #plt.show()
    return fig

# %%
multi_ny_solar.to_csv(r'ny_interpolated_solar.csv')
multi_ny_no_solar.to_csv(r'ny_interpolated_nosolar.csv')

# %%
multi_ny_solar.head()
# Out:
#                     0      1      2      3      4      5      6      7   \
# dataid date
# 27     20190501  0.997  0.750  0.608  1.057  0.518  1.163  0.591  1.155
#        20190502  0.300  0.275  0.296  0.836  0.248  0.269  0.753  0.374
#        20190503  0.352  0.355  0.265  0.219  0.304  0.342  0.336  0.301
#        20190504  0.408  0.311  0.359  0.364  0.266  0.209  0.303  0.413
#        20190505  0.544  0.503  0.781  0.368  0.901  0.369  0.658  0.600
#
#                     8      9   ...     86     87     88     89     90     91  \
# dataid date                    ...
# 27     20190501  0.840  0.697  ...  0.557  1.052  0.561  0.596  0.284  0.394
#        20190502  0.249  0.374  ...  0.741  0.830  0.749  0.703  0.224  0.233
#        20190503  0.304  0.304  ...  0.666  0.477  0.331  0.331  0.316  0.316
#        20190504  0.290  0.209  ...  1.449  0.782  2.082  1.291  1.140  0.811
#        20190505  0.440  0.808  ...  1.196  0.677  0.859  0.458  0.599  0.507
#
#                     92     93     94     95
# dataid date
# 27     20190501  0.356  0.219  0.605  0.304
#        20190502  0.355  0.409  0.294  0.260
#        20190503  0.231  0.277  0.361  0.376
#        20190504  0.592  1.059  0.969  0.665
#        20190505  0.564  0.669  0.540  0.631
#
# [5 rows x 96 columns]

# %%
multi_ny_solar_weekday = pd.to_datetime(multi_ny_solar.reset_index()["date"], format= "%Y%M%d").dt.weekday
multi_ny_solar_building = multi_ny_solar.reset_index()["dataid"]
multi_ny_solar_building.index, multi_ny_solar_weekday.index = multi_ny_solar.index, multi_ny_solar.index
multi_ny_solar_temp = multi_ny_solar.copy()
multi_ny_solar_temp["building"], multi_ny_solar_temp["DOW"] = multi_ny_solar_building, multi_ny_solar_weekday
solar_scaled = multi_ny_solar_temp.groupby(["building","DOW"])\
    .apply(lambda x: x / np.max(abs(x)))\
    .drop(["building", "DOW"], axis=1)

# %%
multi_ny_no_solar_weekday = pd.to_datetime(multi_ny_no_solar.reset_index()["date"], format= "%Y%M%d").dt.weekday
multi_ny_no_solar_building = multi_ny_no_solar.reset_index()["dataid"]
multi_ny_no_solar_building.index, multi_ny_no_solar_weekday.index = multi_ny_no_solar.index, multi_ny_no_solar.index
multi_ny_no_solar_temp = multi_ny_no_solar.copy()
multi_ny_no_solar_temp["building"], multi_ny_no_solar_temp["DOW"] = multi_ny_no_solar_building, multi_ny_no_solar_weekday
multi_ny_no_solar_temp.head()
# Out:
#                      0      1      2      3      4      5      6      7  \
# dataid date
# 558    20190501  0.716  0.830  0.460  0.485  0.822  0.626  0.614  0.751
#        20190502  0.620  0.643  0.656  0.627  0.602  0.580  0.517  0.692
#        20190503  0.723  0.858  0.648  0.632  0.827  0.750  0.580  0.607
#        20190504  0.646  0.721  0.537  0.790  0.496  0.516  0.975  0.596
#        20190505  0.525  0.455  0.501  0.863  0.616  0.604  0.564  0.923
#
#                      8      9  ...     88     89     90     91     92     93  \
# dataid date                    ...
# 558    20190501  0.769  0.685  ...  1.439  1.341  0.785  0.621  0.569  0.699
#        20190502  0.572  0.525  ...  2.130  1.357  1.124  1.164  0.986  0.940
#        20190503  0.713  0.815  ...  1.254  1.035  1.081  0.624  0.542  0.671
#        20190504  0.602  0.902  ...  0.942  0.794  0.758  0.687  0.601  0.683
#        20190505  0.595  0.442  ...  0.769  0.749  1.012  0.598  0.642  0.614
#
#                     94     95  building  DOW
# dataid date
# 558    20190501  0.700  0.927       558    1
#        20190502  0.626  0.764       558    2
#        20190503  0.649  0.813       558    3
#        20190504  0.910  0.642       558    4
#        20190505  0.502  0.540       558    5
#
# [5 rows x 98 columns]

# %%
no_solar_scaled = multi_ny_no_solar_temp.groupby(["building","DOW"])\
    .apply(lambda x: x / np.max(abs(x)))\
    .drop(["building", "DOW"], axis=1)

# %%
solar_norm = solar_scaled.to_numpy()
no_solar_norm = no_solar_scaled.to_numpy()

# %% [markdown]
# ## Solar buildings

# %%
# Using yellowbrick to perform the elbow method
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
model = KMeans(random_state=295) # No need to set number of clusters here

# Visualize distortion scores from k=2 to k=12 clusters
visualizer = KElbowVisualizer(model, k=(2,12),timings=False) # timings=false removes a second line plot of the computation time

visualizer.fit(solar_norm)  # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure of distortions
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# Use yellowbrick to plot silhouette scores
# We want to select k such that the silhouette score is maximized
visualizer = KElbowVisualizer(model, k=(2,12),metric='silhouette',timings=False)

visualizer.fit(solar_norm)  # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure of distortions
# Out:
# C:\Users\orcal\.conda\envs\gurobi\lib\site-packages\yellowbrick\utils\kneed.py:182: YellowbrickWarning: No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\orcal\.conda\envs\gurobi\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\orcal\.conda\envs\gurobi\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
# Perform kmeans clustering
kmeans = KMeans(n_clusters=5,random_state=295)
kmeans.fit(solar_norm)

solar_labels = multi_ny_solar.copy()
solar_labels['kmeans_labels'] = kmeans.labels_

# %%
# Show number of times each building was classified into each label
solar_labels.groupby(by=['dataid','kmeans_labels']).size().unstack(fill_value=0)
# Out:
# kmeans_labels    0   1   2    3    4
# dataid
# 27               3  46  10  100   24
# 142              1  18  53   87   24
# 387              1  49  29   76   28
# 914              5  75  26   42   35
# 950              9  73  12   68   21
# 1222             3  98   3   48   31
# 1240            25   0   0    0  158
# 3000             1  22  70   55   35
# 3488            34  39  44    1   65
# 3517            12  44  44   45   38
# 3700           172   0   0    0   11
# 5058             7  71   9   73   23
# 5587            11  39  68   42   23
# 5679             2  50  41    7   83
# 5997             1  30  35   82   35

# %%
# Use yellowbrick to visualize silhouette scores across each building-day
from yellowbrick.cluster import SilhouetteVisualizer
# is_fitted=True indicates that the KMeans input model is already fitted to our dataset
vis = SilhouetteVisualizer(kmeans, colors='yellowbrick',is_fitted=True)
vis.fit(solar_norm)       
vis.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 2745 Samples in 5 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# Average silhouette score
vis.silhouette_score_
# Out:
# 0.12394850877899548

# %%
# Plot cluster centers
def pad_hours(string):
    if len(string)<2:
        string = '0'+string
    return string

plt.figure(figsize=(12,6))
for cluster_num in range(kmeans.cluster_centers_.shape[0]):
    plt.plot(kmeans.cluster_centers_[cluster_num,:],label='Cluster '+str(cluster_num+1))

hours = np.arange(25)
hours = [pad_hours(str(hour)) for hour in hours]
plt.xticks(ticks = np.arange(0,kmeans.cluster_centers_.shape[1]+4,4),labels=hours)
plt.xlabel('Hour')
plt.ylabel('Energy Use')
plt.ylim([-1,1])
plt.legend()
plt.show()

# %% [markdown]
# ## Non-solar buildings

# %%
# Using yellowbrick to perform the elbow method
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
model = KMeans(random_state=295) # No need to set number of clusters here

# Visualize distortion scores from k=2 to k=12 clusters
visualizer = KElbowVisualizer(model, k=(2,12),timings=False) # timings=false removes a second line plot of the computation time

visualizer.fit(no_solar_norm)  # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure of distortions
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# Use yellowbrick to plot silhouette scores
# We want to select k such that the silhouette score is maximized
visualizer = KElbowVisualizer(model, k=(2,12),metric='silhouette',timings=False)

visualizer.fit(no_solar_norm)  # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure of distortions
# Out:
# C:\Users\orcal\.conda\envs\gurobi\lib\site-packages\yellowbrick\utils\kneed.py:182: YellowbrickWarning: No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\orcal\.conda\envs\gurobi\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\orcal\.conda\envs\gurobi\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
# Perform kmeans clustering
kmeans = KMeans(n_clusters=4,random_state=295)
kmeans.fit(no_solar_norm)

no_solar_labels = multi_ny_no_solar.copy()
no_solar_labels['kmeans_labels'] = kmeans.labels_

# %%
# Show number of times each building was classified into each label
no_solar_labels.groupby(by=['dataid','kmeans_labels']).size().unstack(fill_value=0)
# Out:
# kmeans_labels   0    1    2   3
# dataid
# 558            32  103   41   7
# 1417           27  101   53   2
# 2096           16  110   25  32
# 2318           84    4   48  47
# 2358            7  148    9  19
# 3996           18   69   87   9
# 4283           10   65   43  65
# 4550           15   36  123   9
# 5982           92    8   46  37
# 9053           58   72   39  14

# %%
# Use yellowbrick to visualize silhouette scores across each building-day
from yellowbrick.cluster import SilhouetteVisualizer
# is_fitted=True indicates that the KMeans input model is already fitted to our dataset
vis = SilhouetteVisualizer(kmeans, colors='yellowbrick',is_fitted=True)
vis.fit(no_solar_norm)       
vis.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 1830 Samples in 4 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# Average silhouette score
vis.silhouette_score_
# Out:
# 0.10442860544857846

# %%
# Plot cluster centers
plt.figure(figsize=(12,6))
for cluster_num in range(kmeans.cluster_centers_.shape[0]):
    plt.plot(kmeans.cluster_centers_[cluster_num,:],label='Cluster '+str(cluster_num+1))

hours = np.arange(25)
hours = [pad_hours(str(hour)) for hour in hours]
plt.xticks(ticks = np.arange(0,kmeans.cluster_centers_.shape[1]+4,4),labels=hours)
plt.xlabel('Hour')
plt.ylabel('Energy Use')
plt.ylim([-1,1])
plt.legend()
plt.show()
